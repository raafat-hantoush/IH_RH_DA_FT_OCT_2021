# %% [markdown]
# ## Health Care for All Case Study using Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Pipeline Controller

# %%
hk_df=(load_original_data(path="hk_for_all_pre_processed_data/helathcareforall.csv" ) 
.pipe(lower_case_column_names)
.pipe(rename_columns) 
#.pipe(drop_columns)   
      )

# %%
def load_original_data(path):
    return pd.read_csv(path)

# %%
def lower_case_column_names(hk_df):
    hk_df.columns=[i.lower() for i in hk_df.columns]
    return hk_df

# %%
def rename_columns(hk_df):
    hk_df.rename(columns={"ic2":"med_house_income", "ic3":"med_fam_income","ic4": "avg_fam_income"}, inplace=True )
    return hk_df

# %%
def drop_columns(hk_df) :
    hk_df.drop(columns=["ic5",'pobc1'], inplace=True)
    return hk_df

# %% [markdown]
# ### Quick exploration

# %%
df4.head()
# Out:
#    controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0    190579    CA        M  3200               310             343    83
# 1     42997    FL        F  1567               392             409    27
# 2    132896    OR        F   953               319             455     1
# 3    120189    TX        M   492               244             301     3
# 4    138829    AZ  feamale   847               185             308     0
#
#      ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0  17224     31     32               311             333   3.106061      1
# 1  Hello      4     10               391             434   6.562500      2
# 2  15729      3     45               379             387  15.571429      2
# 3  10818      0     92               260             284  19.375000      0
# 4  11582      3     20               238             225  11.500000     28
#
#     dob domain  target_d
# 0     0     U1       4.0
# 1  1808     C1       7.0
# 2  4410     T1      25.0
# 3     0     T2      25.0
# 4  3601     T2      25.0

# %%
df4.tail(7)
# Out:
#       controln state  gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 1008     43799    FL       F  1044               366             499    15
# 1009    161838    CA       F  1953               304             380    47
# 1010    161838    CA       F  1953               304             380    47
# 1011    161838    CA       F  1953               304             380    47
# 1012    138311    AZ  Female  1708               437             684    36
# 1013    123469    TX       M   561               493             540     1
# 1014    135341    AZ  Female   700               205             295     0
#
#         ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 1008  22427      8     35               318             458  13.166667      2
# 1009  13811     25     43               353             337  13.500000      0
# 1010  13811     25     43               353             337  13.500000      0
# 1011  13811     25     43               353             337  13.500000      0
# 1012  29098      7     19               586             551   9.769231      2
# 1013  16623      5     68               529             506   5.200000      0
# 1014  12713      9     12               221             276  12.857143      0
#
#        dob domain  target_d
# 1008  5801     T2      20.0
# 1009  4212     C2      14.0
# 1010  4212     C2      14.0
# 1011  4212     C2      14.0
# 1012  1403     S1      20.0
# 1013     0     T2       5.0
# 1014     0     C2      12.0

# %%
#print(df4.to_string(header=False))

# %% [markdown]
# #### Renaming columns

# %% [markdown]
# Columns names can be replaced in several ways.
#
# One of them is to provide a new **list of column names** and replace the value of `df.columns`
#
# Another is to use the method `.rename()` which can be applied to a dataframe. This method needs as an input a **dictionary** in which the old column names are the keys, while the new column names are the values.

# %% [markdown]
# #### Excercise:

# %% [markdown]
# Can you figure out how to use list comprehension and string methods in order to have all the column names in lowercase in df4?

# %%
def lower_case_column_names(hk_df):
    return : [i.lower() for i in df4.columns]
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'med_house_income',
#  'avg_fam_income',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'med_house_income',
#  'med_fam_income',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
#df4.columns

df4.columns = [ i.lower() for i in df4.columns]
df4.head()
# Out:
#    controln state   gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  ic2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    ic3    avggift  tcode   dob domain  target_d
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
# Convert the column names to lower case and store them in a list
df4.columns = [elem.lower() for elem in list(df4.columns)]
df4.columns
df4.head()
# Out:
#    controln state   gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  ic2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    ic3    avggift  tcode   dob domain  target_d
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
df4.rename(columns={"ic2":"med_house_income", "ic3":"med_fam_income","ic4": "avg_fam_income"}, inplace=True )

# %% [markdown]
# #### Excercise:

# %% [markdown]
# Can you replace the following columns by the new values using a dictionary?
#
# * "ic2" -> "med_house_income"
# * "ic3" -> "med_fam_income"
# * "ic4" -> "avg_fam_income"

# %%
#df4 = df4.rename(columns={"ic2":"med_house_income", "ic3":"med_fam_income","ic4": "avg_fam_income"})
df4.rename(columns={"ic2":"med_house_income", "ic3":"med_fam_income","ic4": "avg_fam_income"}, inplace=True )

# %%
df4.head()
# Out:
#    controln state   gender   hv1  ic1  avg_fam_income  hvp1    ic5  pobc1  \
# 0    190579    CA        M  3200  310             343    83  17224     31
# 1     42997    FL        F  1567  392             409    27  18631      4
# 2    132896    OR        F   953  319             455     1  15729      3
# 3    120189    TX        M   492  244             301     3  10818      0
# 4    138829    AZ  feamale   847  185             308     0  11582      3
#
#    pobc2  med_house_income  med_fam_income    avggift  tcode   dob domain  \
# 0     32               311             333   3.106061      1     0     U1
# 1     10               391             434   6.562500      2  1808     C1
# 2     45               379             387  15.571429      2  4410     T1
# 3     92               260             284  19.375000      0     0     T2
# 4     20               238             225  11.500000     28  3601     T2
#
#    target_d
# 0       4.0
# 1       7.0
# 2      25.0
# 3      25.0
# 4      25.0

# %%
# use a dictionary to rename specific columns
my_dict = {"ic1":"med_house_income",
 "ic2":"med_fam_income",
 "ic3":"avg_house_income",
 "ic4":"avg_fam_income"}

#df4 = df4.rename(columns=my_dict)
df4.rename(columns=my_dict, inplace=True)
df4.head()
# Out:
#    controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0    190579    CA        M  3200               310             343    83
# 1     42997    FL        F  1567               392             409    27
# 2    132896    OR        F   953               319             455     1
# 3    120189    TX        M   492               244             301     3
# 4    138829    AZ  feamale   847               185             308     0
#
#      ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0  17224     31     32               311             333   3.106061      1
# 1  18631      4     10               391             434   6.562500      2
# 2  15729      3     45               379             387  15.571429      2
# 3  10818      0     92               260             284  19.375000      0
# 4  11582      3     20               238             225  11.500000     28
#
#     dob domain  target_d
# 0     0     U1       4.0
# 1  1808     C1       7.0
# 2  4410     T1      25.0
# 3     0     T2      25.0
# 4  3601     T2      25.0

# %% [markdown]
# #### Deleting columns

# %%
df5 = df4.copy()

# %%
df5.drop(columns=["ic5",'pobc1'], inplace=True)
df5.head()
# Out:
#    controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0    190579    CA        M  3200               310             343    83
# 1     42997    FL        F  1567               392             409    27
# 2    132896    OR        F   953               319             455     1
# 3    120189    TX        M   492               244             301     3
# 4    138829    AZ  feamale   847               185             308     0
#
#    pobc2  med_house_income  med_fam_income    avggift  tcode   dob domain  \
# 0     32               311             333   3.106061      1     0     U1
# 1     10               391             434   6.562500      2  1808     C1
# 2     45               379             387  15.571429      2  4410     T1
# 3     92               260             284  19.375000      0     0     T2
# 4     20               238             225  11.500000     28  3601     T2
#
#    target_d
# 0       4.0
# 1       7.0
# 2      25.0
# 3      25.0
# 4      25.0

# %% [markdown]
# #### Rearanging columns

# %%
list(df5.columns)
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'med_house_income',
#  'avg_fam_income',
#  'hvp1',
#  'pobc2',
#  'med_house_income',
#  'med_fam_income',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %% [markdown]
# Reordering columns is as simple as replace the dataframe with the new ordering of the columns.

# %%
df5 = df5[['controln',
 'state',
 'hv1',
 'avg_fam_income',
 'med_house_income',
 'hvp1',
 'pobc2',
 'med_fam_income',
 'avggift',
 'tcode',
 'dob',
 'domain',
 'target_d']]

df5.head()
# Out:
#    controln state   hv1  avg_fam_income  med_house_income  med_house_income  \
# 0    190579    CA  3200             343               310               311
# 1     42997    FL  1567             409               392               391
# 2    132896    OR   953             455               319               379
# 3    120189    TX   492             301               244               260
# 4    138829    AZ   847             308               185               238
#
#    hvp1  pobc2  med_fam_income    avggift  tcode   dob domain  target_d
# 0    83     32             333   3.106061      1     0     U1       4.0
# 1    27     10             434   6.562500      2  1808     C1       7.0
# 2     1     45             387  15.571429      2  4410     T1      25.0
# 3     3     92             284  19.375000      0     0     T2      25.0
# 4     0     20             225  11.500000     28  3601     T2      25.0

# %% [markdown]
# #### Indexing & subsetting

# %% [markdown]
# Let's see one example of a filter:
#
# select people who have "M" as their gender

# %%
df4.gender.unique()
# Out:
# array(['M', 'F', 'feamale', nan, 'U', 'Male', 'male', 'J', 'female',
#        'Female'], dtype=object)

# %%
df4.gender.describe()
# Out:
# count     985
# unique      9
# top         F
# freq      504
# Name: gender, dtype: object

# %% [markdown]
# We can use several filters but each condition or filter should be placed within parentheses.
#
# Select people who have either "M" or "F" as their gender
#
# & -> and
# | -> or

# %%
df4[(df4['gender'] == "M") | (df4['gender'] == "F")] # & -> and, | -> or
# Out:
#       controln state gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0       190579    CA      M  3200               310             343    83
# 1        42997    FL      F  1567               392             409    27
# 2       132896    OR      F   953               319             455     1
# 3       120189    TX      M   492               244             301     3
# 5       167462    CA      M  2645               644             697    87
# ...        ...   ...    ...   ...               ...             ...   ...
# 1008     43799    FL      F  1044               366             499    15
# 1009    161838    CA      F  1953               304             380    47
# 1010    161838    CA      F  1953               304             380    47
# 1011    161838    CA      F  1953               304             380    47
# 1013    123469    TX      M   561               493             540     1
#
#         ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0     17224     31     32               311             333   3.106061      1
# 1     18631      4     10               391             434   6.562500      2
# 2     15729      3     45               379             387  15.571429      2
# 3     10818      0     92               260             284  19.375000      0
# 5     20782     26     46               655             682   8.750000      0
# ...     ...    ...    ...               ...             ...        ...    ...
# 1008  22427      8     35               318             458  13.166667      2
# 1009  13811     25     43               353             337  13.500000      0
# 1010  13811     25     43               353             337  13.500000      0
# 1011  13811     25     43               353             337  13.500000      0
# 1013  16623      5     68               529             506   5.200000      0
#
#        dob domain  target_d
# 0        0     U1       4.0
# 1     1808     C1       7.0
# 2     4410     T1      25.0
# 3        0     T2      25.0
# 5     3601     S1      15.0
# ...    ...    ...       ...
# 1008  5801     T2      20.0
# 1009  4212     C2      14.0
# 1010  4212     C2      14.0
# 1011  4212     C2      14.0
# 1013     0     T2       5.0
#
# [882 rows x 17 columns]

# %%
df4[(df4['gender'] == "M") | (df4['gender'] == "F")]
#df4[np.where(df4['gender'].isin(["M","F"])) == True]
# Out:
#       controln state gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0       190579    CA      M  3200               310             343    83
# 1        42997    FL      F  1567               392             409    27
# 2       132896    OR      F   953               319             455     1
# 3       120189    TX      M   492               244             301     3
# 5       167462    CA      M  2645               644             697    87
# ...        ...   ...    ...   ...               ...             ...   ...
# 1008     43799    FL      F  1044               366             499    15
# 1009    161838    CA      F  1953               304             380    47
# 1010    161838    CA      F  1953               304             380    47
# 1011    161838    CA      F  1953               304             380    47
# 1013    123469    TX      M   561               493             540     1
#
#         ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0     17224     31     32               311             333   3.106061      1
# 1     18631      4     10               391             434   6.562500      2
# 2     15729      3     45               379             387  15.571429      2
# 3     10818      0     92               260             284  19.375000      0
# 5     20782     26     46               655             682   8.750000      0
# ...     ...    ...    ...               ...             ...        ...    ...
# 1008  22427      8     35               318             458  13.166667      2
# 1009  13811     25     43               353             337  13.500000      0
# 1010  13811     25     43               353             337  13.500000      0
# 1011  13811     25     43               353             337  13.500000      0
# 1013  16623      5     68               529             506   5.200000      0
#
#        dob domain  target_d
# 0        0     U1       4.0
# 1     1808     C1       7.0
# 2     4410     T1      25.0
# 3        0     T2      25.0
# 5     3601     S1      15.0
# ...    ...    ...       ...
# 1008  5801     T2      20.0
# 1009  4212     C2      14.0
# 1010  4212     C2      14.0
# 1011  4212     C2      14.0
# 1013     0     T2       5.0
#
# [882 rows x 17 columns]

# %% [markdown]
# Another example:
#
# Select people who have for which 'target_d' > 15:

# %%
df4[df4['target_d'] > 15]
# Out:
#       controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 2       132896    OR        F   953               319             455     1
# 3       120189    TX        M   492               244             301     3
# 4       138829    AZ  feamale   847               185             308     0
# 9        74235    MI        M   473               327             363     1
# 15      125986    TX        M   533               246             308     1
# ...        ...   ...      ...   ...               ...             ...   ...
# 998     114803    OK        F   911               384             613    16
# 1000     74235    MI        M   473               327             363     1
# 1006    125986    TX        M   533               246             308     1
# 1008     43799    FL        F  1044               366             499    15
# 1012    138311    AZ   Female  1708               437             684    36
#
#         ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 2     15729      3     45               379             387  15.571429      2
# 3     10818      0     92               260             284  19.375000      0
# 4     11582      3     20               238             225  11.500000     28
# 9     12580      0     94               338             348  13.500000      4
# 15    10096      3     75               276             287  13.375000      0
# ...     ...    ...    ...               ...             ...        ...    ...
# 998   31001      2     58               496             497   6.333333     28
# 1000  12580      0     94               338             348  13.500000      4
# 1006  10096      3     75               276             287  13.375000      0
# 1008  22427      8     35               318             458  13.166667      2
# 1012  29098      7     19               586             551   9.769231      2
#
#        dob domain  target_d
# 2     4410     T1      25.0
# 3        0     T2      25.0
# 4     3601     T2      25.0
# 9     4912     T2      26.0
# 15    4610     T2      17.0
# ...    ...    ...       ...
# 998      0     C1      20.0
# 1000  4912     T2      26.0
# 1006  4610     T2      17.0
# 1008  5801     T2      20.0
# 1012  1403     S1      20.0
#
# [393 rows x 17 columns]

# %% [markdown]
# Select people from Florida ("FL")

# %%
df4[df4['state'] == "FL"].head(10)
# Out:
#     controln state gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 1      42997    FL      F  1567               392             409    27
# 17     43799    FL      F  1044               366             499    15
# 29     40058    FL      F  1187               400             469    12
# 35     32807    FL      M   700               327             375     0
# 36       268    FL      F  1765               327             562    44
# 45     11348    FL      M   912               313             442     8
# 50     32972    FL      F   814               268             312     1
# 59     31778    FL      M   986               485             539    11
# 68     14388    FL      M   865               341             432     3
# 70     39667    FL      M   809               358             446     8
#
#       ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 1   18631      4     10               391             434   6.562500      2
# 17  22427      8     35               318             458  13.166667      2
# 29  21608     12     11               448             438  11.666667      2
# 35  11551      9     44               360             355   5.444444   1002
# 36  27674     14      8               465             442  22.380952      0
# 45  18554      6     14               370             379  12.166667      0
# 50  10427      3     46               282             298  10.400000      0
# 59  18013      2     26               495             530  20.111111      1
# 68  15630      7     21               387             392   6.266667   1002
# 70  16099     10     32               389             411  13.714286      0
#
#      dob domain  target_d
# 1   1808     C1       7.0
# 17  5801     T2      20.0
# 29  1007     C2      25.0
# 35  3301     S2       5.0
# 36   607     C1      33.0
# 45     0     C2       5.0
# 50  5511     S2      12.0
# 59  4308     T1      25.0
# 68  6206     S2      10.0
# 70  2209     S2      15.0

# %% [markdown]
# How many people from each gender in Florida?

# %%
df4[(df4['gender'] == "M") & (df4['state'] == "FL") ].shape[0]
# Out:
# 39

# %%
df4[(df4['gender'].isin(["M","F"]) == True) & (df4['state'] == "FL") ].shape
# Out:
# (80, 17)

# %% [markdown]
# We can get how many possible values we have for one particular column using the method `.value_counts()`. This method returns a pandas **Series**

# %%
df4[df4['state'] == "FL"]
# Out:
#       controln state gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 1        42997    FL      F  1567               392             409    27
# 17       43799    FL      F  1044               366             499    15
# 29       40058    FL      F  1187               400             469    12
# 35       32807    FL      M   700               327             375     0
# 36         268    FL      F  1765               327             562    44
# ...        ...   ...    ...   ...               ...             ...   ...
# 950      34591    FL      M   835               413             410     0
# 969      32622    FL      M   533               201             286     4
# 981      43781    FL      M  1069               198             367     7
# 997      34475    FL      M   696               277             355     2
# 1008     43799    FL      F  1044               366             499    15
#
#         ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 1     18631      4     10               391             434   6.562500      2
# 17    22427      8     35               318             458  13.166667      2
# 29    21608     12     11               448             438  11.666667      2
# 35    11551      9     44               360             355   5.444444   1002
# 36    27674     14      8               465             442  22.380952      0
# ...     ...    ...    ...               ...             ...        ...    ...
# 950   14004      7     20               414             429  19.666667      1
# 969   10597      3     25               230             256  23.833333      1
# 981   16759      5     15               257             308   6.125000      1
# 997   12415      3     51               314             325  20.400000      2
# 1008  22427      8     35               318             458  13.166667      2
#
#        dob domain  target_d
# 1     1808     C1       7.0
# 17    5801     T2      20.0
# 29    1007     C2      25.0
# 35    3301     S2       5.0
# 36     607     C1      33.0
# ...    ...    ...       ...
# 950   3401     S2      23.0
# 969    805     R2      47.0
# 981   3001     C2      10.0
# 997   3009     R2      20.0
# 1008  5801     T2      20.0
#
# [85 rows x 17 columns]

# %%
type(df4[df4['state'] == "FL"])
# Out:
# pandas.core.frame.DataFrame

# %%
df4[df4['state'] == "FL"]['gender']
# Out:
# 1       F
# 17      F
# 29      F
# 35      M
# 36      F
#        ..
# 950     M
# 969     M
# 981     M
# 997     M
# 1008    F
# Name: gender, Length: 85, dtype: object

# %%
type(df4[df4['state'] == "FL"]['gender'])
# Out:
# pandas.core.series.Series

# %%
df4[df4['state'] == "FL"]['gender'].value_counts(dropna=False)
# Out:
# F      41
# M      39
# NaN     4
# J       1
# Name: gender, dtype: int64

# %%
df4[df4['state'] == "FL"]['gender'].unique()
# Out:
# array(['F', 'M', nan, 'J'], dtype=object)

# %%
df4['gender'].value_counts(dropna=True)
# Out:
# F          504
# M          378
# male        32
# female      30
# Female      15
# U           13
# Male         5
# feamale      4
# J            4
# Name: gender, dtype: int64

# %%
type(df4['gender'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df4['gender'].value_counts()['Female']
# Out:
# 15

# %%
df4['gender'].value_counts().sum()
# Out:
# 985

# %% [markdown]
# The method `.value_counts()` doesn't show the missing values. If we want to know if there are any, we can provide the option `dropna=False`.

# %%
df4['gender'].value_counts(dropna=False).sum()
# Out:
# 1015

# %%
df4['gender'].value_counts(dropna=False)
# Out:
# F          504
# M          378
# male        32
# NaN         30
# female      30
# Female      15
# U           13
# Male         5
# feamale      4
# J            4
# Name: gender, dtype: int64

# %% [markdown]
# We can know what are the unique values of a column using the method `.unique()`, and then the method `.tolist()` to castthe resulting **Series** into a list.

# %%
df4["gender"].unique().tolist()
# Out:
# ['M', 'F', 'feamale', nan, 'U', 'Male', 'male', 'J', 'female', 'Female']

# %%
df4.shape
# Out:
# (1015, 17)

# %% [markdown]
# The method `.info()` allow us to obtain information about every column in the dataframe

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   controln          1015 non-null   int64
#  1   state             1015 non-null   object
#  2   gender            985 non-null    object
#  3   hv1               1015 non-null   int64
#  4   med_house_income  1015 non-null   int64
#  5   avg_fam_income    1015 non-null   int64
#  6   hvp1              1015 non-null   int64
#  7   ic5               1015 non-null   int64
#  8   pobc1             1015 non-null   int64
#  9   pobc2             1015 non-null   int64
#  10  med_house_income  1015 non-null   int64
#  11  med_fam_income    1015 non-null   int64
#  12  avggift           1015 non-null   float64
#  13  tcode             1015 non-null   int64
#  14  dob               1015 non-null   int64
#  15  domain            1015 non-null   object
#  16  target_d          1015 non-null   float64
# dtypes: float64(2), int64(12), object(3)
# memory usage: 134.9+ KB

# %% [markdown]
# The method `.describe()` give us a **dataframe** with an statistical summary of every column

# %%
temp = df4.describe().transpose()
temp
# Out:
#                    count          mean           std        min           25%  \
# controln          1015.0  96351.472906  57107.922941  67.000000  44557.500000
# hv1               1015.0   1137.401970   1048.030341   0.000000    532.500000
# med_house_income  1015.0    349.104433    172.584516   0.000000    236.000000
# avg_fam_income    1015.0    440.786207    178.826938   0.000000    322.000000
# hvp1              1015.0     15.424631     28.600285   0.000000      0.000000
# ic5               1015.0  16434.610837   9695.004583   0.000000  11064.500000
# pobc1             1015.0      7.115271     10.036399   0.000000      1.000000
# pobc2             1015.0     55.825616     21.376039   0.000000     42.000000
# med_house_income  1015.0    397.914286    185.040178   0.000000    282.000000
# med_fam_income    1015.0    395.131034    167.825716   0.000000    282.000000
# avggift           1015.0     11.970404     15.314822   2.439815      7.107026
# tcode             1015.0     95.952709   1514.092209   0.000000      0.000000
# dob               1015.0   2787.850246   2057.395908   0.000000   1101.000000
# target_d          1015.0     15.481773     10.591076   1.000000     10.000000
#
#                            50%        75%       max
# controln          96031.000000  147839.50  191138.0
# hv1                 770.000000    1258.50    5970.0
# med_house_income    311.000000     419.50    1386.0
# avg_fam_income      399.000000     518.50    1273.0
# hvp1                  1.000000      12.00      99.0
# ic5               14119.000000   18674.50   95913.0
# pobc1                 3.000000       9.00      72.0
# pobc2                58.000000      73.00      96.0
# med_house_income    359.000000     467.50    1500.0
# med_fam_income      355.000000     466.00    1208.0
# avggift              10.190476      14.25     450.0
# tcode                 1.000000       2.00   39002.0
# dob                2711.000000    4501.00    9310.0
# target_d             14.000000      20.00     100.0

# %% [markdown]
# #### Indexing

# %% [markdown]
# Select rows 5 and 6:

# %%
df4.loc[5:6]
# Out:
#    controln state gender   hv1  med_house_income  avg_fam_income  hvp1    ic5  \
# 5    167462    CA      M  2645               644             697    87  20782
# 6    160401    CA      F  1952               335             398    48  15290
#
#    pobc1  pobc2  med_house_income  med_fam_income  avggift  tcode   dob  \
# 5     26     46               655             682     8.75      0  3601
# 6      6     55               365             367    13.00     28  3101
#
#   domain  target_d
# 5     S1      15.0
# 6     T2      13.0

# %%
df4.iloc[5:6]
# Out:
#    controln state gender   hv1  med_house_income  avg_fam_income  hvp1    ic5  \
# 5    167462    CA      M  2645               644             697    87  20782
#
#    pobc1  pobc2  med_house_income  med_fam_income  avggift  tcode   dob  \
# 5     26     46               655             682     8.75      0  3601
#
#   domain  target_d
# 5     S1      15.0

# %%
df4.iloc[[5,7],[0,2]]
# Out:
#    controln gender
# 5    167462      M
# 7    174934      F

# %%
df4.head()
# Out:
#    controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0    190579    CA        M  3200               310             343    83
# 1     42997    FL        F  1567               392             409    27
# 2    132896    OR        F   953               319             455     1
# 3    120189    TX        M   492               244             301     3
# 4    138829    AZ  feamale   847               185             308     0
#
#      ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0  17224     31     32               311             333   3.106061      1
# 1  18631      4     10               391             434   6.562500      2
# 2  15729      3     45               379             387  15.571429      2
# 3  10818      0     92               260             284  19.375000      0
# 4  11582      3     20               238             225  11.500000     28
#
#     dob domain  target_d
# 0     0     U1       4.0
# 1  1808     C1       7.0
# 2  4410     T1      25.0
# 3     0     T2      25.0
# 4  3601     T2      25.0

# %% [markdown]
# Select columns "gender" and "ic2", and rows 4 to 10:

# %%
df4.gender

# %%
df4.gender.unique()
# Out:
# array(['M', 'F', 'feamale', nan, 'U', 'Male', 'male', 'J', 'female',
#        'Female'], dtype=object)

# %%
df4.iloc[4:10,[2,1]]
# Out:
#     gender state
# 4  feamale    AZ
# 5        M    CA
# 6        F    CA
# 7        F    OR
# 8        F    CA
# 9        M    MI

# %%
df4.iloc[4:10,:]
# Out:
#    controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 4    138829    AZ  feamale   847               185             308     0
# 5    167462    CA        M  2645               644             697    87
# 6    160401    CA        F  1952               335             398    48
# 7    174934    OR        F  1305               391             471    19
# 8      2020    CA        F  3556               735             805    98
# 9     74235    MI        M   473               327             363     1
#
#      ic5  pobc1  pobc2  med_house_income  med_fam_income  avggift  tcode  \
# 4  11582      3     20               238             225    11.50     28
# 5  20782     26     46               655             682     8.75      0
# 6  15290      6     55               365             367    13.00     28
# 7  19716      7     40               456             448     7.00     28
# 8  34382      9     55               701             838     7.35      2
# 9  12580      0     94               338             348    13.50      4
#
#     dob domain  target_d
# 4  3601     T2      25.0
# 5  3601     S1      15.0
# 6  3101     T2      13.0
# 7     0     S2       5.0
# 8  2401     S1       7.0
# 9  4912     T2      26.0

# %%
df4.iloc[:,4:10]
# Out:
#       med_house_income  avg_fam_income  hvp1    ic5  pobc1  pobc2
# 0                  310             343    83  17224     31     32
# 1                  392             409    27  18631      4     10
# 2                  319             455     1  15729      3     45
# 3                  244             301     3  10818      0     92
# 4                  185             308     0  11582      3     20
# ...                ...             ...   ...    ...    ...    ...
# 1010               304             380    47  13811     25     43
# 1011               304             380    47  13811     25     43
# 1012               437             684    36  29098      7     19
# 1013               493             540     1  16623      5     68
# 1014               205             295     0  12713      9     12
#
# [1015 rows x 6 columns]

# %% [markdown]
# #### Correcting data types
#
# With `to_numeric`

# %%
df4['avggift'] = pd.to_numeric(df4['avggift'])

# %% [markdown]
# #### Removing duplicates
#
# We can remove duplicate rows with the method `drop_duplicates()`

# %%
df4.gender.drop_duplicates()
# Out:
#      controln state   gender   hv1  med_house_income  avg_fam_income  hvp1  \
# 0      190579    CA        M  3200               310             343    83
# 1       42997    FL        F  1567               392             409    27
# 2      132896    OR        F   953               319             455     1
# 3      120189    TX        M   492               244             301     3
# 4      138829    AZ  feamale   847               185             308     0
# ..        ...   ...      ...   ...               ...             ...   ...
# 995    156152    CA        F  1115               313             391     4
# 996     67177    MI        F   709               504             539     0
# 997     34475    FL        M   696               277             355     2
# 998    114803    OK        F   911               384             613    16
# 999     15332    NC        M   723               371             456     0
#
#        ic5  pobc1  pobc2  med_house_income  med_fam_income    avggift  tcode  \
# 0    17224     31     32               311             333   3.106061      1
# 1    18631      4     10               391             434   6.562500      2
# 2    15729      3     45               379             387  15.571429      2
# 3    10818      0     92               260             284  19.375000      0
# 4    11582      3     20               238             225  11.500000     28
# ..     ...    ...    ...               ...             ...        ...    ...
# 995  16625      9     37               340             354  11.437500      2
# 996  17801      2     79               515             522   9.937500      0
# 997  12415      3     51               314             325  20.400000      2
# 998  31001      2     58               496             497   6.333333     28
# 999  18915      6     47               414             398   6.538462      1
#
#       dob domain  target_d
# 0       0     U1       4.0
# 1    1808     C1       7.0
# 2    4410     T1      25.0
# 3       0     T2      25.0
# 4    3601     T2      25.0
# ..    ...    ...       ...
# 995  2501     T2      16.0
# 996  2609     S2      12.0
# 997  3009     R2      20.0
# 998     0     C1      20.0
# 999  1701     C1      10.0
#
# [1000 rows x 17 columns]

# %% [markdown]
# #### Adding a new column

# %%
df5.shape
# Out:
# (1015, 14)

# %%
df5.shape[0]
# Out:
# 1015

# %%
import numpy as np

df5["not_so_many_randoms"] = np.random.random(size=df5.shape[0])
df5.head()
# Out:
#    controln state   hv1  avg_fam_income  med_house_income  med_house_income  \
# 0    190579    CA  3200             343               310               311
# 1     42997    FL  1567             409               392               391
# 2    132896    OR   953             455               319               379
# 3    120189    TX   492             301               244               260
# 4    138829    AZ   847             308               185               238
#
#    hvp1  pobc2  med_fam_income    avggift  tcode   dob domain  target_d  \
# 0    83     32             333   3.106061      1     0     U1       4.0
# 1    27     10             434   6.562500      2  1808     C1       7.0
# 2     1     45             387  15.571429      2  4410     T1      25.0
# 3     3     92             284  19.375000      0     0     T2      25.0
# 4     0     20             225  11.500000     28  3601     T2      25.0
#
#    not_so_many_randoms
# 0             0.474340
# 1             0.540555
# 2             0.962724
# 3             0.726859
# 4             0.015204

# %%
list(df5.columns)
# Out:
# ['controln',
#  'state',
#  'hv1',
#  'avg_fam_income',
#  'med_house_income',
#  'med_house_income',
#  'hvp1',
#  'pobc2',
#  'med_fam_income',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d',
#  'not_so_many_randoms',
#  'empty_col']

# %%
df5[['controln',
 'state',
 'hv1',
 'avg_fam_income',
 'med_house_income',
 'hvp1',
 'pobc2',
 'med_fam_income',
 'avggift',
 'tcode',
 'dob',
 'domain',
 'not_so_many_randoms',
 'target_d',
 'empty_col'] ]
# Out:
#       controln state   hv1  avg_fam_income  med_house_income  \
# 0       190579    CA  3200             343               310
# 1        42997    FL  1567             409               392
# 2       132896    OR   953             455               319
# 3       120189    TX   492             301               244
# 4       138829    AZ   847             308               185
# ...        ...   ...   ...             ...               ...
# 1010    161838    CA  1953             380               304
# 1011    161838    CA  1953             380               304
# 1012    138311    AZ  1708             684               437
# 1013    123469    TX   561             540               493
# 1014    135341    AZ   700             295               205
#
#       med_house_income  hvp1  pobc2  med_fam_income    avggift  tcode   dob  \
# 0                  311    83     32             333   3.106061      1     0
# 1                  391    27     10             434   6.562500      2  1808
# 2                  379     1     45             387  15.571429      2  4410
# 3                  260     3     92             284  19.375000      0     0
# 4                  238     0     20             225  11.500000     28  3601
# ...                ...   ...    ...             ...        ...    ...   ...
# 1010               353    47     43             337  13.500000      0  4212
# 1011               353    47     43             337  13.500000      0  4212
# 1012               586    36     19             551   9.769231      2  1403
# 1013               529     1     68             506   5.200000      0     0
# 1014               221     0     12             276  12.857143      0     0
#
#      domain  not_so_many_randoms  target_d empty_col
# 0        U1             0.474340       4.0
# 1        C1             0.540555       7.0
# 2        T1             0.962724      25.0
# 3        T2             0.726859      25.0
# 4        T2             0.015204      25.0
# ...     ...                  ...       ...       ...
# 1010     C2             0.719353      14.0
# 1011     C2             0.538853      14.0
# 1012     S1             0.119708      20.0
# 1013     T2             0.420153       5.0
# 1014     C2             0.141750      12.0
#
# [1015 rows x 16 columns]

# %% [markdown]
# #### Summary functions
#
# sum(), mean(), max()...

# %%
df4.med_house_income.min()
# Out:
# med_house_income    0
# med_house_income    0
# dtype: int64

# %%
df5["hv1"].sum()
# Out:
# 1154463

# %%
np.sum(df5["hv1"])
# Out:
# 1154463

# %% [markdown]
# ## EDA and Plotting

# %%
hk_data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0      430.0  466  28.000000      1  1901     C2     100.0
# 1      415.0  410   5.666667      0     0     T2       7.0
# 2      340.0  361   4.111111      0  2501     C2       5.0
# 3      407.0  399  27.277778      0  2208     T2      38.0
# 4      280.0  316   6.000000     28     0     C2       5.0
# ...      ...  ...        ...    ...   ...    ...       ...
# 1002   609.0  579  11.666667      0     0     C2      15.0
# 1003  1004.0  893  20.000000      1  4401     S1      20.0
# 1004   413.0  404   7.300000      0  4404     C2      10.0
# 1005   419.0  476  16.400000      1  5001     S2      23.0
# 1006   277.0  292   9.818182      2  2201     S2      12.0
#
# [1007 rows x 17 columns]

# %%
plt.scatter(x=hk_data['IC2'], y=hk_data['IC3'])
plt.show()

# %%
plt.scatter(x=data['ic2'], y=data['ic3'])
plt.show()

data['median_home_val'].hist()
plt.show()

data['median_home_val'].hist(bins=40)
plt.show()

sns.distplot(data['median_home_val'], bins=20)
plt.show()

data[['median_home_val']].boxplot()
plt.show()

sns.boxplot(y="median_home_val", data=data)
plt.show()

sns.boxplot(x = 'gender',y='median_home_val', data=data)
plt.show()

sns.barplot(x="gender", y="median_home_val", data=data)
plt.show()

plt.figure(figsize=(16,16))
sns.barplot(y="state", x="median_home_val", hue= 'gender', data=data)
plt.show()

# %% [markdown]
# #### Write a csv
#
# With `to_csv`

# %%
#df5.to_csv("fsdsd/cleaned_file.csv")
