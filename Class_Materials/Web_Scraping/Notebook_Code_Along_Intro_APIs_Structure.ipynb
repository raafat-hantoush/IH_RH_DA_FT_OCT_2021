# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '19027907810',
#   'type': 'PushEvent',
#   'actor': {'id': 69902583,
#    'login': 'SG-GIT-HUB',
#    'display_login': 'SG-GIT-HUB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SG-GIT-HUB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69902583?'},
#   'repo': {'id': 421312252,
#    'name': 'SG-GIT-HUB/React-For-Beginners-Starter-Files',
#    'url': 'https://api.github.com/repos/SG-GIT-HUB/React-For-Beginners-Starter-Files'},
#   'payload': {'push_id': 8459975109,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '77d44c954dc481c443f575208048e9302138dc24',
#    'before': 'b5e38dc888cb53a9446ab4753fbf5274a37c23af',
#    'commits': [{'sha': '77d44c954dc481c443f575208048e9302138dc24',
#      'author': {'email': '69902583+SG-GIT-HUB@users.noreply.github.com',
#       'name': 'SG-GIT-HUB'},
#      'message': 'lesson 19',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SG-GIT-HUB/React-For-Beginners-Starter-Files/commits/77d44c954dc481c443f575208048e9302138dc24'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907832',
#   'type': 'CreateEvent',
#   'actor': {'id': 75158103,
#    'login': 'chen8908',
#    'display_login': 'chen8908',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chen8908',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75158103?'},
#   'repo': {'id': 431383749,
#    'name': 'chen8908/chen8908.github.io',
#    'url': 'https://api.github.com/repos/chen8908/chen8908.github.io'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907838',
#   'type': 'CreateEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 431383747,
#    'name': 'devhub-blue-sea/org-public-empty-csc-repo-ap-southeast-1',
#    'url': 'https://api.github.com/repos/devhub-blue-sea/org-public-empty-csc-repo-ap-southeast-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Empty Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z',
#   'org': {'id': 53108288,
#    'login': 'devhub-blue-sea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devhub-blue-sea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108288?'}},
#  {'id': '19027907799',
#   'type': 'PushEvent',
#   'actor': {'id': 93641609,
#    'login': 'patrick-hoell',
#    'display_login': 'patrick-hoell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patrick-hoell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93641609?'},
#   'repo': {'id': 431377784,
#    'name': 'patrick-hoell/mslearn-tailspin-spacegame-web',
#    'url': 'https://api.github.com/repos/patrick-hoell/mslearn-tailspin-spacegame-web'},
#   'payload': {'push_id': 8459975104,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '070a8e30407a56c98257b7f018dc579a9665000c',
#    'before': 'f236243d0bf2ab89278687e66645c4f6c11a8ef3',
#    'commits': [{'sha': '070a8e30407a56c98257b7f018dc579a9665000c',
#      'author': {'email': '93641609+patrick-hoell@users.noreply.github.com',
#       'name': 'patrick-hoell'},
#      'message': 'Set up CI with Azure Pipelines\n\n[skip ci]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/patrick-hoell/mslearn-tailspin-spacegame-web/commits/070a8e30407a56c98257b7f018dc579a9665000c'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907796',
#   'type': 'PushEvent',
#   'actor': {'id': 45362986,
#    'login': 'joashdev',
#    'display_login': 'joashdev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joashdev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45362986?'},
#   'repo': {'id': 430790785,
#    'name': 'joashdev/pomotime',
#    'url': 'https://api.github.com/repos/joashdev/pomotime'},
#   'payload': {'push_id': 8459975098,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fa5d71054d9447779001f3fb5fa55e622c8496c0',
#    'before': 'df89c256fa41347010409ed46e0e443a2ec9b095',
#    'commits': [{'sha': 'fa5d71054d9447779001f3fb5fa55e622c8496c0',
#      'author': {'email': '45362986+joashdev@users.noreply.github.com',
#       'name': 'Kent Joash Zamudio'},
#      'message': 'Code cleanup and created 404 route',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joashdev/pomotime/commits/fa5d71054d9447779001f3fb5fa55e622c8496c0'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907769',
#   'type': 'PushEvent',
#   'actor': {'id': 50871412,
#    'login': 'jerryIsHere',
#    'display_login': 'jerryIsHere',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jerryIsHere',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50871412?'},
#   'repo': {'id': 413235913,
#    'name': 'jerryIsHere/K-Cube',
#    'url': 'https://api.github.com/repos/jerryIsHere/K-Cube'},
#   'payload': {'push_id': 8459975087,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '48e13cb17d348bb251248b42468282d708394bba',
#    'before': 'd199ad61a21f94de5fb76f5d377e03b2b56f59b2',
#    'commits': [{'sha': '48e13cb17d348bb251248b42468282d708394bba',
#      'author': {'email': '14075364d@connect.polyu.hk', 'name': 'jerryIsHere'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryIsHere/K-Cube/commits/48e13cb17d348bb251248b42468282d708394bba'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907797',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 388644227,
#    'name': 'Pinheiro-Lucas/Pinheiro-Lucas',
#    'url': 'https://api.github.com/repos/Pinheiro-Lucas/Pinheiro-Lucas'},
#   'payload': {'push_id': 8459975099,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '47a98fe0785e487ee10eeadc74840f37a73c2618',
#    'before': '15562ecd6f4efe55514181a0aa62b82954dd2d5f',
#    'commits': [{'sha': '47a98fe0785e487ee10eeadc74840f37a73c2618',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pinheiro-Lucas/Pinheiro-Lucas/commits/47a98fe0785e487ee10eeadc74840f37a73c2618'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907792',
#   'type': 'PushEvent',
#   'actor': {'id': 52286662,
#    'login': 'karata-sc',
#    'display_login': 'karata-sc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karata-sc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52286662?'},
#   'repo': {'id': 431373387,
#    'name': 'keito1029/communication_share',
#    'url': 'https://api.github.com/repos/keito1029/communication_share'},
#   'payload': {'push_id': 8459975102,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bcf5cec461ebe6597be0476b63d21c93bdf6c310',
#    'before': 'a589c250df1556b9b70a6faa04b9defa5e00fda0',
#    'commits': [{'sha': 'bcf5cec461ebe6597be0476b63d21c93bdf6c310',
#      'author': {'email': '52286662+karata-sc@users.noreply.github.com',
#       'name': 'karata-sc'},
#      'message': 'latest\n\nme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/keito1029/communication_share/commits/bcf5cec461ebe6597be0476b63d21c93bdf6c310'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907747',
#   'type': 'PushEvent',
#   'actor': {'id': 9650581,
#    'login': 'jiyuujin',
#    'display_login': 'jiyuujin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jiyuujin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9650581?'},
#   'repo': {'id': 313598056,
#    'name': 'jiyuujin/payment-lambda',
#    'url': 'https://api.github.com/repos/jiyuujin/payment-lambda'},
#   'payload': {'push_id': 8459975086,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9dff87b77754d74553ab06582e26217310c90aea',
#    'before': '1ede334e3b6b1b4e0cdc051d117205ad6f99b1bc',
#    'commits': [{'sha': 'e77030b85e1b1b7d138d9d6451639a57fd4b3a3c',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': '[DEPENDABOT]: Update stripe requirement from ^8.188.0 to ^8.191.0\n\nUpdates the requirements on [stripe](https://github.com/stripe/stripe-node) to permit the latest version.\n- [Release notes](https://github.com/stripe/stripe-node/releases)\n- [Changelog](https://github.com/stripe/stripe-node/blob/master/CHANGELOG.md)\n- [Commits](https://github.com/stripe/stripe-node/compare/v8.188.0...v8.191.0)\n\n---\nupdated-dependencies:\n- dependency-name: stripe\n  dependency-type: direct:production\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/jiyuujin/payment-lambda/commits/e77030b85e1b1b7d138d9d6451639a57fd4b3a3c'},
#     {'sha': '9dff87b77754d74553ab06582e26217310c90aea',
#      'author': {'email': 'jiyuujinunite@gmail.com', 'name': 'jiyuujin'},
#      'message': 'Merge pull request #121 from jiyuujin/dependabot/npm_and_yarn/stripe-tw-8.191.0\n\n[DEPENDABOT]: Update stripe requirement from ^8.188.0 to ^8.191.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jiyuujin/payment-lambda/commits/9dff87b77754d74553ab06582e26217310c90aea'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907773',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 369191018,
#    'name': 'sd462355991111/JDDJ',
#    'url': 'https://api.github.com/repos/sd462355991111/JDDJ'},
#   'payload': {'action': 'closed',
#    'number': 54,
#    'pull_request': {'url': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54',
#     'id': 787655159,
#     'node_id': 'PR_kwDOFgFoas4u8qn3',
#     'html_url': 'https://github.com/sd462355991111/JDDJ/pull/54',
#     'diff_url': 'https://github.com/sd462355991111/JDDJ/pull/54.diff',
#     'patch_url': 'https://github.com/sd462355991111/JDDJ/pull/54.patch',
#     'issue_url': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/54',
#     'number': 54,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] main from passerby-b:main',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See [Commits](/sd462355991111/JDDJ/pull/54/commits) and [Changes](/sd462355991111/JDDJ/pull/54/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2021-11-24T07:15:53Z',
#     'updated_at': '2021-11-24T07:15:56Z',
#     'closed_at': '2021-11-24T07:15:55Z',
#     'merged_at': '2021-11-24T07:15:55Z',
#     'merge_commit_sha': '53732c34b2c82804fd536df58c0cd75c6e665760',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 3017399392,
#       'node_id': 'MDU6TGFiZWwzMDE3Mzk5Mzky',
#       'url': 'https://api.github.com/repos/sd462355991111/JDDJ/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54/commits',
#     'review_comments_url': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54/comments',
#     'review_comment_url': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/54/comments',
#     'statuses_url': 'https://api.github.com/repos/sd462355991111/JDDJ/statuses/53732c34b2c82804fd536df58c0cd75c6e665760',
#     'head': {'label': 'passerby-b:main',
#      'ref': 'main',
#      'sha': '53732c34b2c82804fd536df58c0cd75c6e665760',
#      'user': {'login': 'passerby-b',
#       'id': 40885345,
#       'node_id': 'MDQ6VXNlcjQwODg1MzQ1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/40885345?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/passerby-b',
#       'html_url': 'https://github.com/passerby-b',
#       'followers_url': 'https://api.github.com/users/passerby-b/followers',
#       'following_url': 'https://api.github.com/users/passerby-b/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/passerby-b/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/passerby-b/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/passerby-b/subscriptions',
#       'organizations_url': 'https://api.github.com/users/passerby-b/orgs',
#       'repos_url': 'https://api.github.com/users/passerby-b/repos',
#       'events_url': 'https://api.github.com/users/passerby-b/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/passerby-b/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 358509180,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNTg1MDkxODA=',
#       'name': 'JDDJ',
#       'full_name': 'passerby-b/JDDJ',
#       'private': False,
#       'owner': {'login': 'passerby-b',
#        'id': 40885345,
#        'node_id': 'MDQ6VXNlcjQwODg1MzQ1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/40885345?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/passerby-b',
#        'html_url': 'https://github.com/passerby-b',
#        'followers_url': 'https://api.github.com/users/passerby-b/followers',
#        'following_url': 'https://api.github.com/users/passerby-b/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/passerby-b/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/passerby-b/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/passerby-b/subscriptions',
#        'organizations_url': 'https://api.github.com/users/passerby-b/orgs',
#        'repos_url': 'https://api.github.com/users/passerby-b/repos',
#        'events_url': 'https://api.github.com/users/passerby-b/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/passerby-b/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/passerby-b/JDDJ',
#       'description': '京东到家果园庄园脚本,电报群:https://t.me/passerbyb2021',
#       'fork': False,
#       'url': 'https://api.github.com/repos/passerby-b/JDDJ',
#       'forks_url': 'https://api.github.com/repos/passerby-b/JDDJ/forks',
#       'keys_url': 'https://api.github.com/repos/passerby-b/JDDJ/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/passerby-b/JDDJ/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/passerby-b/JDDJ/teams',
#       'hooks_url': 'https://api.github.com/repos/passerby-b/JDDJ/hooks',
#       'issue_events_url': 'https://api.github.com/repos/passerby-b/JDDJ/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/passerby-b/JDDJ/events',
#       'assignees_url': 'https://api.github.com/repos/passerby-b/JDDJ/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/passerby-b/JDDJ/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/passerby-b/JDDJ/tags',
#       'blobs_url': 'https://api.github.com/repos/passerby-b/JDDJ/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/passerby-b/JDDJ/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/passerby-b/JDDJ/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/passerby-b/JDDJ/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/passerby-b/JDDJ/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/passerby-b/JDDJ/languages',
#       'stargazers_url': 'https://api.github.com/repos/passerby-b/JDDJ/stargazers',
#       'contributors_url': 'https://api.github.com/repos/passerby-b/JDDJ/contributors',
#       'subscribers_url': 'https://api.github.com/repos/passerby-b/JDDJ/subscribers',
#       'subscription_url': 'https://api.github.com/repos/passerby-b/JDDJ/subscription',
#       'commits_url': 'https://api.github.com/repos/passerby-b/JDDJ/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/passerby-b/JDDJ/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/passerby-b/JDDJ/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/passerby-b/JDDJ/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/passerby-b/JDDJ/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/passerby-b/JDDJ/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/passerby-b/JDDJ/merges',
#       'archive_url': 'https://api.github.com/repos/passerby-b/JDDJ/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/passerby-b/JDDJ/downloads',
#       'issues_url': 'https://api.github.com/repos/passerby-b/JDDJ/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/passerby-b/JDDJ/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/passerby-b/JDDJ/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/passerby-b/JDDJ/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/passerby-b/JDDJ/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/passerby-b/JDDJ/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/passerby-b/JDDJ/deployments',
#       'created_at': '2021-04-16T07:12:01Z',
#       'updated_at': '2021-11-24T06:30:01Z',
#       'pushed_at': '2021-11-24T06:29:58Z',
#       'git_url': 'git://github.com/passerby-b/JDDJ.git',
#       'ssh_url': 'git@github.com:passerby-b/JDDJ.git',
#       'clone_url': 'https://github.com/passerby-b/JDDJ.git',
#       'svn_url': 'https://github.com/passerby-b/JDDJ',
#       'homepage': '',
#       'size': 1254,
#       'stargazers_count': 613,
#       'watchers_count': 613,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 335,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 335,
#       'open_issues': 1,
#       'watchers': 613,
#       'default_branch': 'main'}},
#     'base': {'label': 'sd462355991111:main',
#      'ref': 'main',
#      'sha': 'c79a718cc0084cb30be5775e031ca1d3ed0d6a48',
#      'user': {'login': 'sd462355991111',
#       'id': 78030698,
#       'node_id': 'MDQ6VXNlcjc4MDMwNjk4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/78030698?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sd462355991111',
#       'html_url': 'https://github.com/sd462355991111',
#       'followers_url': 'https://api.github.com/users/sd462355991111/followers',
#       'following_url': 'https://api.github.com/users/sd462355991111/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sd462355991111/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sd462355991111/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sd462355991111/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sd462355991111/orgs',
#       'repos_url': 'https://api.github.com/users/sd462355991111/repos',
#       'events_url': 'https://api.github.com/users/sd462355991111/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sd462355991111/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 369191018,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNjkxOTEwMTg=',
#       'name': 'JDDJ',
#       'full_name': 'sd462355991111/JDDJ',
#       'private': False,
#       'owner': {'login': 'sd462355991111',
#        'id': 78030698,
#        'node_id': 'MDQ6VXNlcjc4MDMwNjk4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/78030698?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sd462355991111',
#        'html_url': 'https://github.com/sd462355991111',
#        'followers_url': 'https://api.github.com/users/sd462355991111/followers',
#        'following_url': 'https://api.github.com/users/sd462355991111/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sd462355991111/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sd462355991111/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sd462355991111/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sd462355991111/orgs',
#        'repos_url': 'https://api.github.com/users/sd462355991111/repos',
#        'events_url': 'https://api.github.com/users/sd462355991111/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sd462355991111/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/sd462355991111/JDDJ',
#       'description': '京东到家果园庄园脚本,电报群:https://t.me/passerbyb2021',
#       'fork': True,
#       'url': 'https://api.github.com/repos/sd462355991111/JDDJ',
#       'forks_url': 'https://api.github.com/repos/sd462355991111/JDDJ/forks',
#       'keys_url': 'https://api.github.com/repos/sd462355991111/JDDJ/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sd462355991111/JDDJ/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sd462355991111/JDDJ/teams',
#       'hooks_url': 'https://api.github.com/repos/sd462355991111/JDDJ/hooks',
#       'issue_events_url': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/sd462355991111/JDDJ/events',
#       'assignees_url': 'https://api.github.com/repos/sd462355991111/JDDJ/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/sd462355991111/JDDJ/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/sd462355991111/JDDJ/tags',
#       'blobs_url': 'https://api.github.com/repos/sd462355991111/JDDJ/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/sd462355991111/JDDJ/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/sd462355991111/JDDJ/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/sd462355991111/JDDJ/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/sd462355991111/JDDJ/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/sd462355991111/JDDJ/languages',
#       'stargazers_url': 'https://api.github.com/repos/sd462355991111/JDDJ/stargazers',
#       'contributors_url': 'https://api.github.com/repos/sd462355991111/JDDJ/contributors',
#       'subscribers_url': 'https://api.github.com/repos/sd462355991111/JDDJ/subscribers',
#       'subscription_url': 'https://api.github.com/repos/sd462355991111/JDDJ/subscription',
#       'commits_url': 'https://api.github.com/repos/sd462355991111/JDDJ/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/sd462355991111/JDDJ/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/sd462355991111/JDDJ/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/sd462355991111/JDDJ/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/sd462355991111/JDDJ/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/sd462355991111/JDDJ/merges',
#       'archive_url': 'https://api.github.com/repos/sd462355991111/JDDJ/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/sd462355991111/JDDJ/downloads',
#       'issues_url': 'https://api.github.com/repos/sd462355991111/JDDJ/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/sd462355991111/JDDJ/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/sd462355991111/JDDJ/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/sd462355991111/JDDJ/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/sd462355991111/JDDJ/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/sd462355991111/JDDJ/deployments',
#       'created_at': '2021-05-20T11:53:30Z',
#       'updated_at': '2021-11-23T09:54:21Z',
#       'pushed_at': '2021-11-24T07:15:55Z',
#       'git_url': 'git://github.com/sd462355991111/JDDJ.git',
#       'ssh_url': 'git@github.com:sd462355991111/JDDJ.git',
#       'clone_url': 'https://github.com/sd462355991111/JDDJ.git',
#       'svn_url': 'https://github.com/sd462355991111/JDDJ',
#       'homepage': '',
#       'size': 1254,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54'},
#      'html': {'href': 'https://github.com/sd462355991111/JDDJ/pull/54'},
#      'issue': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/54'},
#      'comments': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/issues/54/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/pulls/54/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/sd462355991111/JDDJ/statuses/53732c34b2c82804fd536df58c0cd75c6e665760'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 5,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907731',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 289198022,
#    'name': 'magdapoppins/magdapoppins',
#    'url': 'https://api.github.com/repos/magdapoppins/magdapoppins'},
#   'payload': {'push_id': 8459975080,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '01b5f25df47c05330a02b2ccb1f5e5c4a03e6c0b',
#    'before': '98e0fd1c495b054dde92ff9bc72eec7ad08487fb',
#    'commits': [{'sha': '01b5f25df47c05330a02b2ccb1f5e5c4a03e6c0b',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'Actions'},
#      'message': 'Set the zen 🪐',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/magdapoppins/magdapoppins/commits/01b5f25df47c05330a02b2ccb1f5e5c4a03e6c0b'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907732',
#   'type': 'PushEvent',
#   'actor': {'id': 24356597,
#    'login': 'foramgandhi12',
#    'display_login': 'foramgandhi12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/foramgandhi12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24356597?'},
#   'repo': {'id': 428845279,
#    'name': 'foramgandhi12/MedBase',
#    'url': 'https://api.github.com/repos/foramgandhi12/MedBase'},
#   'payload': {'push_id': 8459975064,
#    'size': 12,
#    'distinct_size': 1,
#    'ref': 'refs/heads/foram',
#    'head': 'e8dba81370e9b1d58b1b46fd1d10f34bfa7883d7',
#    'before': 'f368edd5bf9a996415d9cdfce5d1340d57af4a09',
#    'commits': [{'sha': '413606aeaf162452c13315cf3e1230ff0f85c161',
#      'author': {'email': '80480634+AryanS0301@users.noreply.github.com',
#       'name': 'AryanS0301'},
#      'message': 'Added Kinjals Photo',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/413606aeaf162452c13315cf3e1230ff0f85c161'},
#     {'sha': 'd7126baaf8d69bdb57d381db4178cb47450bb433',
#      'author': {'email': '32719043+rutvishah859@users.noreply.github.com',
#       'name': 'Rutvi Shah'},
#      'message': 'Added receptionist dashboard and integrated the dashboard.php template',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/d7126baaf8d69bdb57d381db4178cb47450bb433'},
#     {'sha': 'bc014d6c42c1866a93a9b608bf385d8bedf0e594',
#      'author': {'email': '80480634+AryanS0301@users.noreply.github.com',
#       'name': 'AryanS0301'},
#      'message': 'changed the about page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/bc014d6c42c1866a93a9b608bf385d8bedf0e594'},
#     {'sha': '9ca6c6ba450f23418fa07ab62879b97b12e25eaa',
#      'author': {'email': '32719043+rutvishah859@users.noreply.github.com',
#       'name': 'Rutvi Shah'},
#      'message': 'Added the widgets and sidebar elements in the receptionist dashboard',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/9ca6c6ba450f23418fa07ab62879b97b12e25eaa'},
#     {'sha': '71ea6e86b148ee0d41899bd064ce36d4c6ce83fa',
#      'author': {'email': '32719043+rutvishah859@users.noreply.github.com',
#       'name': 'Rutvi Shah'},
#      'message': 'Added a sidebar php page and made a patients registration page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/71ea6e86b148ee0d41899bd064ce36d4c6ce83fa'},
#     {'sha': '0783bb44c4427dfd7f396c57edd23191ac23e49a',
#      'author': {'email': '32719043+rutvishah859@users.noreply.github.com',
#       'name': 'Rutvi Shah'},
#      'message': "Merge branch 'ReceptionistDashboard' into main",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/0783bb44c4427dfd7f396c57edd23191ac23e49a'},
#     {'sha': '449dc14e133f155bee9ed45be525ccb3b8213329',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': 'added icons to about page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/449dc14e133f155bee9ed45be525ccb3b8213329'},
#     {'sha': 'bbd9129207601673ee1ae54a1fd6455407f8c52b',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': 'updated about page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/bbd9129207601673ee1ae54a1fd6455407f8c52b'},
#     {'sha': '32ee6646fb2b1618fae9f9c5f82a79be22d8e5e2',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': 'updated cards on about page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/32ee6646fb2b1618fae9f9c5f82a79be22d8e5e2'},
#     {'sha': '5c0df182df7ad8a1c854a2d3a1063e848668e07f',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': 'updated card format',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/5c0df182df7ad8a1c854a2d3a1063e848668e07f'},
#     {'sha': '96d49319f25a6214be3a32e8283a86edb5bd84b3',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': 'updated formatting for about page cards',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/96d49319f25a6214be3a32e8283a86edb5bd84b3'},
#     {'sha': 'e8dba81370e9b1d58b1b46fd1d10f34bfa7883d7',
#      'author': {'email': 'foram4444@gmail.com', 'name': 'Foram'},
#      'message': "Merge branch 'main' into foram",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/foramgandhi12/MedBase/commits/e8dba81370e9b1d58b1b46fd1d10f34bfa7883d7'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907759',
#   'type': 'PushEvent',
#   'actor': {'id': 82928831,
#    'login': 'imjoud',
#    'display_login': 'imjoud',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/imjoud',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82928831?'},
#   'repo': {'id': 429472355,
#    'name': 'imjoud/imjoud.github.io',
#    'url': 'https://api.github.com/repos/imjoud/imjoud.github.io'},
#   'payload': {'push_id': 8459975078,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6666d69ed0cec11c3333219a5067bab07702ea29',
#    'before': '7452c3ec7002c2bf96f0f5e19f6e0a1a0fd5e4b3',
#    'commits': [{'sha': '6666d69ed0cec11c3333219a5067bab07702ea29',
#      'author': {'email': '82928831+imjoud@users.noreply.github.com',
#       'name': 'hey'},
#      'message': 'Update style.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/imjoud/imjoud.github.io/commits/6666d69ed0cec11c3333219a5067bab07702ea29'}]},
#   'public': True,
#   'created_at': '2021-11-24T07:15:56Z'},
#  {'id': '19027907714',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49859594,
#    'login': 'Speedwag00n',
#    'display_login': 'Speedwag00n',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Speedwag00n',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49859594?'},
#   'repo': {'id': 114762520,
#    'name': 'luxteam/rpr_pipelines',
#    'url': 'https://api.github.com/repos/luxteam/rpr_pipelines'},
#   'payload': {'action': 'opened',
#    'number': 794,
#    'pull_request': {'url': 'https://api.github.com/repos/luxteam/rpr_pipelines/pulls/794',
#     'id': 787655185,
#     'node_id': 'PR_kwDOBtcjGM4u8qoR',
#     'html_url': 'https://github.com/luxteam/rpr_pipelines/pull/794',
#     'diff_url': 'https://github.com/luxteam/rpr_pipelines/pull/794.diff',
#     'patch_url': 'https://github.com/luxteam/rpr_pipelines/pull/794.patch',
#     'issue_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/issues/794',
#     'number': 794,
#     'state': 'open',
#     'locked': False,
#     'title': 'Ducktape for Houdini autotests',
#     'user': {'login': 'Speedwag00n',
#      'id': 49859594,
#      'node_id': 'MDQ6VXNlcjQ5ODU5NTk0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/49859594?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Speedwag00n',
#      'html_url': 'https://github.com/Speedwag00n',
#      'followers_url': 'https://api.github.com/users/Speedwag00n/followers',
#      'following_url': 'https://api.github.com/users/Speedwag00n/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Speedwag00n/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Speedwag00n/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Speedwag00n/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Speedwag00n/orgs',
#      'repos_url': 'https://api.github.com/users/Speedwag00n/repos',
#      'events_url': 'https://api.github.com/users/Speedwag00n/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Speedwag00n/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-11-24T07:15:55Z',
#     'updated_at': '2021-11-24T07:15:55Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/pulls/794/commits',
#     'review_comments_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/pulls/794/comments',
#     'review_comment_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/issues/794/comments',
#     'statuses_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/statuses/49c716de4db9a789404ba3cbd5d3f1c09fa02451',
#     'head': {'label': 'luxteam:inemankov/houdini_ducktape',
#      'ref': 'inemankov/houdini_ducktape',
#      'sha': '49c716de4db9a789404ba3cbd5d3f1c09fa02451',
#      'user': {'login': 'luxteam',
#       'id': 33544610,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNTQ0NjEw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/33544610?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/luxteam',
#       'html_url': 'https://github.com/luxteam',
#       'followers_url': 'https://api.github.com/users/luxteam/followers',
#       'following_url': 'https://api.github.com/users/luxteam/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/luxteam/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/luxteam/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/luxteam/subscriptions',
#       'organizations_url': 'https://api.github.com/users/luxteam/orgs',
#       'repos_url': 'https://api.github.com/users/luxteam/repos',
#       'events_url': 'https://api.github.com/users/luxteam/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/luxteam/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 114762520,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTQ3NjI1MjA=',
#       'name': 'rpr_pipelines',
#       'full_name': 'luxteam/rpr_pipelines',
#       'private': False,
#       'owner': {'login': 'luxteam',
#        'id': 33544610,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNTQ0NjEw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/33544610?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/luxteam',
#        'html_url': 'https://github.com/luxteam',
#        'followers_url': 'https://api.github.com/users/luxteam/followers',
#        'following_url': 'https://api.github.com/users/luxteam/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/luxteam/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/luxteam/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/luxteam/subscriptions',
#        'organizations_url': 'https://api.github.com/users/luxteam/orgs',
#        'repos_url': 'https://api.github.com/users/luxteam/repos',
#        'events_url': 'https://api.github.com/users/luxteam/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/luxteam/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/luxteam/rpr_pipelines',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/luxteam/rpr_pipelines',
#       'forks_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/forks',
#       'keys_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/teams',
#       'hooks_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/hooks',
#       'issue_events_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/events',
#       'assignees_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/tags',
#       'blobs_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/languages',
#       'stargazers_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/stargazers',
#       'contributors_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/contributors',
#       'subscribers_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/subscribers',
#       'subscription_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/subscription',
#       'commits_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/merges',
#       'archive_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/downloads',
#       'issues_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/luxteam/rpr_pipelines/deployments',
#       'created_at': '2017-12-19T12:27:13Z',
#       'updated_at': '2021-11-17T12:38:18Z',
#       'pushed_at': '2021-11-24T07:15:56Z',
#       'git_url': 'git://github.com/luxteam/rpr_pipelines.git',
#       'ssh_url': 'git@github.com:luxteam/rpr_pipelines.git',
#       'clone_url': 'https://github.com/luxteam/rpr_pipelines.git',
#       'svn_url': 'https://github.com/luxteam/rpr_pipelines',
#       'homepage': '',
#       'size': 8811,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Groovy',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 5,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 5,
#       'open_issues': 6,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'luxteam:master',
#      'ref': 'master',
#      'sha': 'a9dde3c9a2536e3502defacd2a0e2f7da90a5976',
#      'user': {'login': 'luxteam',
#       'id': 33544610,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNTQ0NjEw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/33544610?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/luxteam',
#       'html_url': 'https://github.com/luxteam',
#       'followers_url': 'https://api.github.com/users/luxteam/followers',
#       'following_url': 'https://api.github.com/users/luxteam/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/luxteam/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/luxteam/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/luxteam/subscriptions',
#       'organizations_url': 'https://api.github.com/users/luxteam/orgs',
#       'repos_url': 'https://api.github.com/users/luxteam/repos',
#       'events_url': 'https://api.github.com/users/luxteam/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/luxteam/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 114762520,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTQ3NjI1MjA=',
#       'name': 'rpr_pipelines',
#       'full_name': 'luxteam/rpr_pipelines',
#       'private': False,
#       'owner': {'login': 'luxteam',
#        'id': 33544610,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNTQ0NjEw',
# ...
#       'following_url': 'https://api.github.com/users/jiyuujin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jiyuujin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jiyuujin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jiyuujin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jiyuujin/orgs',
#       'repos_url': 'https://api.github.com/users/jiyuujin/repos',
#       'events_url': 'https://api.github.com/users/jiyuujin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jiyuujin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 313598056,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTM1OTgwNTY=',
#       'name': 'payment-lambda',
#       'full_name': 'jiyuujin/payment-lambda',
#       'private': False,
#       'owner': {'login': 'jiyuujin',
#        'id': 9650581,
#        'node_id': 'MDQ6VXNlcjk2NTA1ODE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9650581?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jiyuujin',
#        'html_url': 'https://github.com/jiyuujin',
#        'followers_url': 'https://api.github.com/users/jiyuujin/followers',
#        'following_url': 'https://api.github.com/users/jiyuujin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jiyuujin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jiyuujin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jiyuujin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jiyuujin/orgs',
#        'repos_url': 'https://api.github.com/users/jiyuujin/repos',
#        'events_url': 'https://api.github.com/users/jiyuujin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jiyuujin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jiyuujin/payment-lambda',
#       'description': ':dollar: Payment server on AWS Lambda',
#       'fork': False,
#       'url': 'https://api.github.com/repos/jiyuujin/payment-lambda',
#       'forks_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/forks',
#       'keys_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/teams',
#       'hooks_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/events',
#       'assignees_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/tags',
#       'blobs_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/languages',
#       'stargazers_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/subscription',
#       'commits_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/merges',
#       'archive_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/downloads',
#       'issues_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/deployments',
#       'created_at': '2020-11-17T11:27:59Z',
#       'updated_at': '2021-11-24T07:11:32Z',
#       'pushed_at': '2021-11-24T07:15:55Z',
#       'git_url': 'git://github.com/jiyuujin/payment-lambda.git',
#       'ssh_url': 'git@github.com:jiyuujin/payment-lambda.git',
#       'clone_url': 'https://github.com/jiyuujin/payment-lambda.git',
#       'svn_url': 'https://github.com/jiyuujin/payment-lambda',
#       'homepage': 'https://jiyuujin.github.io/payment-lambda/',
#       'size': 41,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['aws-lambda', 'stripe'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jiyuujin:master',
#      'ref': 'master',
#      'sha': '1ede334e3b6b1b4e0cdc051d117205ad6f99b1bc',
#      'user': {'login': 'jiyuujin',
#       'id': 9650581,
#       'node_id': 'MDQ6VXNlcjk2NTA1ODE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9650581?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jiyuujin',
#       'html_url': 'https://github.com/jiyuujin',
#       'followers_url': 'https://api.github.com/users/jiyuujin/followers',
#       'following_url': 'https://api.github.com/users/jiyuujin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jiyuujin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jiyuujin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jiyuujin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jiyuujin/orgs',
#       'repos_url': 'https://api.github.com/users/jiyuujin/repos',
#       'events_url': 'https://api.github.com/users/jiyuujin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jiyuujin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 313598056,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTM1OTgwNTY=',
#       'name': 'payment-lambda',
#       'full_name': 'jiyuujin/payment-lambda',
#       'private': False,
#       'owner': {'login': 'jiyuujin',
#        'id': 9650581,
#        'node_id': 'MDQ6VXNlcjk2NTA1ODE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9650581?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jiyuujin',
#        'html_url': 'https://github.com/jiyuujin',
#        'followers_url': 'https://api.github.com/users/jiyuujin/followers',
#        'following_url': 'https://api.github.com/users/jiyuujin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jiyuujin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jiyuujin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jiyuujin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jiyuujin/orgs',
#        'repos_url': 'https://api.github.com/users/jiyuujin/repos',
#        'events_url': 'https://api.github.com/users/jiyuujin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jiyuujin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jiyuujin/payment-lambda',
#       'description': ':dollar: Payment server on AWS Lambda',
#       'fork': False,
#       'url': 'https://api.github.com/repos/jiyuujin/payment-lambda',
#       'forks_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/forks',
#       'keys_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/teams',
#       'hooks_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/events',
#       'assignees_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/tags',
#       'blobs_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/languages',
#       'stargazers_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/subscription',
#       'commits_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/merges',
#       'archive_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/downloads',
#       'issues_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jiyuujin/payment-lambda/deployments',
#       'created_at': '2020-11-17T11:27:59Z',
#       'updated_at': '2021-11-24T07:11:32Z',
#       'pushed_at': '2021-11-24T07:15:55Z',
#       'git_url': 'git://github.com/jiyuujin/payment-lambda.git',
#       'ssh_url': 'git@github.com:jiyuujin/payment-lambda.git',
#       'clone_url': 'https://github.com/jiyuujin/payment-lambda.git',
#       'svn_url': 'https://github.com/jiyuujin/payment-lambda',
#       'homepage': 'https://jiyuujin.github.io/payment-lambda/',
#       'size': 41,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['aws-lambda', 'stripe'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls/121'},
#      'html': {'href': 'https://github.com/jiyuujin/payment-lambda/pull/121'},
#      'issue': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/121'},
#      'comments': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/issues/121/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls/121/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/pulls/121/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jiyuujin/payment-lambda/statuses/e77030b85e1b1b7d138d9d6451639a57fd4b3a3c'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'jiyuujin',
#      'id': 9650581,
#      'node_id': 'MDQ6VXNlcjk2NTA1ODE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9650581?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jiyuujin',
#      'html_url': 'https://github.com/jiyuujin',
#      'followers_url': 'https://api.github.com/users/jiyuujin/followers',
#      'following_url': 'https://api.github.com/users/jiyuujin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jiyuujin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jiyuujin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jiyuujin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jiyuujin/orgs',
#      'repos_url': 'https://api.github.com/users/jiyuujin/repos',
#      'events_url': 'https://api.github.com/users/jiyuujin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jiyuujin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-11-24T07:15:55Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id              type  \
# 0   19027907810         PushEvent
# 1   19027907832       CreateEvent
# 2   19027907838       CreateEvent
# 3   19027907799         PushEvent
# 4   19027907796         PushEvent
# 5   19027907769         PushEvent
# 6   19027907797         PushEvent
# 7   19027907792         PushEvent
# 8   19027907747         PushEvent
# 9   19027907773  PullRequestEvent
# 10  19027907731         PushEvent
# 11  19027907732         PushEvent
# 12  19027907759         PushEvent
# 13  19027907714  PullRequestEvent
# 14  19027907734       CreateEvent
# 15  19027907697         PushEvent
# 16  19027907692         PushEvent
# 17  19027907712        WatchEvent
# 18  19027907693         PushEvent
# 19  19027907704         PushEvent
# 20  19027907680         PushEvent
# 21  19027907672       CreateEvent
# 22  19027907685         PushEvent
# 23  19027907661         ForkEvent
# 24  19027907664         PushEvent
# 25  19027907674         PushEvent
# 26  19027907670        WatchEvent
# 27  19027907658         PushEvent
# 28  19027907642        WatchEvent
# 29  19027907641  PullRequestEvent
#
#                                                 actor  \
# 0   {'id': 69902583, 'login': 'SG-GIT-HUB', 'displ...
# 1   {'id': 75158103, 'login': 'chen8908', 'display...
# 2   {'id': 71354125, 'login': 'aws-connector-for-g...
# 3   {'id': 93641609, 'login': 'patrick-hoell', 'di...
# 4   {'id': 45362986, 'login': 'joashdev', 'display...
# 5   {'id': 50871412, 'login': 'jerryIsHere', 'disp...
# 6   {'id': 41898282, 'login': 'github-actions[bot]...
# 7   {'id': 52286662, 'login': 'karata-sc', 'displa...
# 8   {'id': 9650581, 'login': 'jiyuujin', 'display_...
# 9   {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 10  {'id': 41898282, 'login': 'github-actions[bot]...
# 11  {'id': 24356597, 'login': 'foramgandhi12', 'di...
# 12  {'id': 82928831, 'login': 'imjoud', 'display_l...
# 13  {'id': 49859594, 'login': 'Speedwag00n', 'disp...
# 14  {'id': 80814896, 'login': 'TaeYunAhn', 'displa...
# 15  {'id': 59991511, 'login': 'w-endo', 'display_l...
# 16  {'id': 41898282, 'login': 'github-actions[bot]...
# 17  {'id': 40334071, 'login': 'alicanertop', 'disp...
# 18  {'id': 22478978, 'login': 'LastSprint', 'displ...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 69158844, 'login': 'project20911', 'dis...
# 21  {'id': 6956310, 'login': 'jimmyzhen', 'display...
# 22  {'id': 90423959, 'login': 'pringle97', 'displa...
# 23  {'id': 13044753, 'login': 'menghaniv', 'displa...
# 24  {'id': 91318945, 'login': 'PablioKonst88', 'di...
# 25  {'id': 85677360, 'login': 'shuming-yu', 'displ...
# 26  {'id': 89684029, 'login': 'Phongdho', 'display...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 63482, 'login': 'defstream', 'display_l...
# 29  {'id': 9650581, 'login': 'jiyuujin', 'display_...
#
#                                                  repo  \
# 0   {'id': 421312252, 'name': 'SG-GIT-HUB/React-Fo...
# 1   {'id': 431383749, 'name': 'chen8908/chen8908.g...
# 2   {'id': 431383747, 'name': 'devhub-blue-sea/org...
# 3   {'id': 431377784, 'name': 'patrick-hoell/mslea...
# 4   {'id': 430790785, 'name': 'joashdev/pomotime',...
# 5   {'id': 413235913, 'name': 'jerryIsHere/K-Cube'...
# 6   {'id': 388644227, 'name': 'Pinheiro-Lucas/Pinh...
# 7   {'id': 431373387, 'name': 'keito1029/communica...
# 8   {'id': 313598056, 'name': 'jiyuujin/payment-la...
# 9   {'id': 369191018, 'name': 'sd462355991111/JDDJ...
# 10  {'id': 289198022, 'name': 'magdapoppins/magdap...
# 11  {'id': 428845279, 'name': 'foramgandhi12/MedBa...
# 12  {'id': 429472355, 'name': 'imjoud/imjoud.githu...
# 13  {'id': 114762520, 'name': 'luxteam/rpr_pipelin...
# 14  {'id': 431383745, 'name': 'TaeYunAhn/tahn.gith...
# 15  {'id': 399304076, 'name': 'w-endo/MaoEditor202...
# 16  {'id': 407312546, 'name': 'giovanniryan/giovan...
# 17  {'id': 313330998, 'name': 'bradtraversy/50proj...
# 18  {'id': 371601902, 'name': 'LastSprint/feedback...
# 19  {'id': 378400741, 'name': 'DataHerb/dataset-da...
# 20  {'id': 287324470, 'name': 'project20911/TestRe...
# 21  {'id': 332571994, 'name': 'MoTrPAC/exercise-tr...
# 22  {'id': 430985226, 'name': 'pringle97/weather-d...
# 23  {'id': 406307445, 'name': 'prayas-energy/PIER'...
# 24  {'id': 416715002, 'name': 'PablioKonst88/GB', ...
# 25  {'id': 431016243, 'name': 'shuming-yu/todolist...
# 26  {'id': 135614069, 'name': 'sudheerj/reactjs-in...
# 27  {'id': 383514868, 'name': 'benaisc/demo-MMM-pa...
# 28  {'id': 283529901, 'name': 'bobg/subcmd', 'url'...
# 29  {'id': 313598056, 'name': 'jiyuujin/payment-la...
#
#                                               payload  public  \
# 0   {'push_id': 8459975109, 'size': 1, 'distinct_s...    True
# 1   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 2   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 3   {'push_id': 8459975104, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 8459975098, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 8459975087, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 8459975099, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 8459975102, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 8459975086, 'size': 2, 'distinct_s...    True
# 9   {'action': 'closed', 'number': 54, 'pull_reque...    True
# 10  {'push_id': 8459975080, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 8459975064, 'size': 12, 'distinct_...    True
# 12  {'push_id': 8459975078, 'size': 1, 'distinct_s...    True
# 13  {'action': 'opened', 'number': 794, 'pull_requ...    True
# 14  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 15  {'push_id': 8459975056, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 8459975049, 'size': 1, 'distinct_s...    True
# 17                              {'action': 'started'}    True
# 18  {'push_id': 8459975069, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 8459975065, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 8459975050, 'size': 1, 'distinct_s...    True
# 21  {'ref': 'dev', 'ref_type': 'branch', 'master_b...    True
# 22  {'push_id': 8459975070, 'size': 1, 'distinct_s...    True
# 23  {'forkee': {'id': 431383746, 'node_id': 'R_kgD...    True
# 24  {'push_id': 8459975051, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 8459975060, 'size': 1, 'distinct_s...    True
# 26                              {'action': 'started'}    True
# 27  {'push_id': 8459975041, 'size': 1, 'distinct_s...    True
# 28                              {'action': 'started'}    True
# 29  {'action': 'closed', 'number': 121, 'pull_requ...    True
#
#               created_at                                                org
# 0   2021-11-24T07:15:56Z                                                NaN
# 1   2021-11-24T07:15:56Z                                                NaN
# 2   2021-11-24T07:15:56Z  {'id': 53108288, 'login': 'devhub-blue-sea', '...
# 3   2021-11-24T07:15:56Z                                                NaN
# 4   2021-11-24T07:15:56Z                                                NaN
# 5   2021-11-24T07:15:56Z                                                NaN
# 6   2021-11-24T07:15:56Z                                                NaN
# 7   2021-11-24T07:15:56Z                                                NaN
# 8   2021-11-24T07:15:56Z                                                NaN
# 9   2021-11-24T07:15:56Z                                                NaN
# 10  2021-11-24T07:15:56Z                                                NaN
# 11  2021-11-24T07:15:56Z                                                NaN
# 12  2021-11-24T07:15:56Z                                                NaN
# 13  2021-11-24T07:15:56Z  {'id': 33544610, 'login': 'luxteam', 'gravatar...
# 14  2021-11-24T07:15:56Z                                                NaN
# 15  2021-11-24T07:15:56Z                                                NaN
# 16  2021-11-24T07:15:56Z                                                NaN
# 17  2021-11-24T07:15:56Z                                                NaN
# 18  2021-11-24T07:15:56Z                                                NaN
# 19  2021-11-24T07:15:56Z  {'id': 60699748, 'login': 'DataHerb', 'gravata...
# 20  2021-11-24T07:15:56Z                                                NaN
# 21  2021-11-24T07:15:56Z  {'id': 47675013, 'login': 'MoTrPAC', 'gravatar...
# 22  2021-11-24T07:15:56Z                                                NaN
# 23  2021-11-24T07:15:56Z  {'id': 16575131, 'login': 'prayas-energy', 'gr...
# 24  2021-11-24T07:15:56Z                                                NaN
# 25  2021-11-24T07:15:56Z                                                NaN
# 26  2021-11-24T07:15:56Z                                                NaN
# 27  2021-11-24T07:15:55Z                                                NaN
# 28  2021-11-24T07:15:55Z                                                NaN
# 29  2021-11-24T07:15:55Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id              type  public            created_at  actor.id  \
# 0   19027907810         PushEvent    True  2021-11-24T07:15:56Z  69902583
# 1   19027907832       CreateEvent    True  2021-11-24T07:15:56Z  75158103
# 2   19027907838       CreateEvent    True  2021-11-24T07:15:56Z  71354125
# 3   19027907799         PushEvent    True  2021-11-24T07:15:56Z  93641609
# 4   19027907796         PushEvent    True  2021-11-24T07:15:56Z  45362986
# 5   19027907769         PushEvent    True  2021-11-24T07:15:56Z  50871412
# 6   19027907797         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 7   19027907792         PushEvent    True  2021-11-24T07:15:56Z  52286662
# 8   19027907747         PushEvent    True  2021-11-24T07:15:56Z   9650581
# 9   19027907773  PullRequestEvent    True  2021-11-24T07:15:56Z  39814207
# 10  19027907731         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 11  19027907732         PushEvent    True  2021-11-24T07:15:56Z  24356597
# 12  19027907759         PushEvent    True  2021-11-24T07:15:56Z  82928831
# 13  19027907714  PullRequestEvent    True  2021-11-24T07:15:56Z  49859594
# 14  19027907734       CreateEvent    True  2021-11-24T07:15:56Z  80814896
# 15  19027907697         PushEvent    True  2021-11-24T07:15:56Z  59991511
# 16  19027907692         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 17  19027907712        WatchEvent    True  2021-11-24T07:15:56Z  40334071
# 18  19027907693         PushEvent    True  2021-11-24T07:15:56Z  22478978
# 19  19027907704         PushEvent    True  2021-11-24T07:15:56Z  41898282
# 20  19027907680         PushEvent    True  2021-11-24T07:15:56Z  69158844
# 21  19027907672       CreateEvent    True  2021-11-24T07:15:56Z   6956310
# 22  19027907685         PushEvent    True  2021-11-24T07:15:56Z  90423959
# 23  19027907661         ForkEvent    True  2021-11-24T07:15:56Z  13044753
# 24  19027907664         PushEvent    True  2021-11-24T07:15:56Z  91318945
# 25  19027907674         PushEvent    True  2021-11-24T07:15:56Z  85677360
# 26  19027907670        WatchEvent    True  2021-11-24T07:15:56Z  89684029
# 27  19027907658         PushEvent    True  2021-11-24T07:15:55Z  41898282
# 28  19027907642        WatchEvent    True  2021-11-24T07:15:55Z     63482
# 29  19027907641  PullRequestEvent    True  2021-11-24T07:15:55Z   9650581
#
#                       actor.login       actor.display_login actor.gravatar_id  \
# 0                      SG-GIT-HUB                SG-GIT-HUB
# 1                        chen8908                  chen8908
# 2   aws-connector-for-github[bot]  aws-connector-for-github
# 3                   patrick-hoell             patrick-hoell
# 4                        joashdev                  joashdev
# 5                     jerryIsHere               jerryIsHere
# 6             github-actions[bot]            github-actions
# 7                       karata-sc                 karata-sc
# 8                        jiyuujin                  jiyuujin
# 9                       pull[bot]                      pull
# 10            github-actions[bot]            github-actions
# 11                  foramgandhi12             foramgandhi12
# 12                         imjoud                    imjoud
# 13                    Speedwag00n               Speedwag00n
# 14                      TaeYunAhn                 TaeYunAhn
# 15                         w-endo                    w-endo
# 16            github-actions[bot]            github-actions
# 17                    alicanertop               alicanertop
# 18                     LastSprint                LastSprint
# 19            github-actions[bot]            github-actions
# 20                   project20911              project20911
# 21                      jimmyzhen                 jimmyzhen
# 22                      pringle97                 pringle97
# 23                      menghaniv                 menghaniv
# 24                  PablioKonst88             PablioKonst88
# 25                     shuming-yu                shuming-yu
# 26                       Phongdho                  Phongdho
# 27            github-actions[bot]            github-actions
# 28                      defstream                 defstream
# 29                       jiyuujin                  jiyuujin
#
#                                             actor.url  \
# 0             https://api.github.com/users/SG-GIT-HUB
# 1               https://api.github.com/users/chen8908
# 2   https://api.github.com/users/aws-connector-for...
# 3          https://api.github.com/users/patrick-hoell
# 4               https://api.github.com/users/joashdev
# 5            https://api.github.com/users/jerryIsHere
# 6    https://api.github.com/users/github-actions[bot]
# 7              https://api.github.com/users/karata-sc
# 8               https://api.github.com/users/jiyuujin
# 9              https://api.github.com/users/pull[bot]
# 10   https://api.github.com/users/github-actions[bot]
# 11         https://api.github.com/users/foramgandhi12
# 12                https://api.github.com/users/imjoud
# 13           https://api.github.com/users/Speedwag00n
# 14             https://api.github.com/users/TaeYunAhn
# 15                https://api.github.com/users/w-endo
# 16   https://api.github.com/users/github-actions[bot]
# 17           https://api.github.com/users/alicanertop
# 18            https://api.github.com/users/LastSprint
# 19   https://api.github.com/users/github-actions[bot]
# 20          https://api.github.com/users/project20911
# 21             https://api.github.com/users/jimmyzhen
# 22             https://api.github.com/users/pringle97
# 23             https://api.github.com/users/menghaniv
# 24         https://api.github.com/users/PablioKonst88
# 25            https://api.github.com/users/shuming-yu
# 26              https://api.github.com/users/Phongdho
# 27   https://api.github.com/users/github-actions[bot]
# 28             https://api.github.com/users/defstream
# 29              https://api.github.com/users/jiyuujin
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/69902583?  ...
# 1   https://avatars.githubusercontent.com/u/75158103?  ...
# 2   https://avatars.githubusercontent.com/u/71354125?  ...
# 3   https://avatars.githubusercontent.com/u/93641609?  ...
# 4   https://avatars.githubusercontent.com/u/45362986?  ...
# 5   https://avatars.githubusercontent.com/u/50871412?  ...
# 6   https://avatars.githubusercontent.com/u/41898282?  ...
# 7   https://avatars.githubusercontent.com/u/52286662?  ...
# 8    https://avatars.githubusercontent.com/u/9650581?  ...
# 9   https://avatars.githubusercontent.com/u/39814207?  ...
# 10  https://avatars.githubusercontent.com/u/41898282?  ...
# 11  https://avatars.githubusercontent.com/u/24356597?  ...
# 12  https://avatars.githubusercontent.com/u/82928831?  ...
# 13  https://avatars.githubusercontent.com/u/49859594?  ...
# 14  https://avatars.githubusercontent.com/u/80814896?  ...
# 15  https://avatars.githubusercontent.com/u/59991511?  ...
# 16  https://avatars.githubusercontent.com/u/41898282?  ...
# 17  https://avatars.githubusercontent.com/u/40334071?  ...
# 18  https://avatars.githubusercontent.com/u/22478978?  ...
# 19  https://avatars.githubusercontent.com/u/41898282?  ...
# 20  https://avatars.githubusercontent.com/u/69158844?  ...
# 21   https://avatars.githubusercontent.com/u/6956310?  ...
# 22  https://avatars.githubusercontent.com/u/90423959?  ...
# 23  https://avatars.githubusercontent.com/u/13044753?  ...
# 24  https://avatars.githubusercontent.com/u/91318945?  ...
# 25  https://avatars.githubusercontent.com/u/85677360?  ...
# 26  https://avatars.githubusercontent.com/u/89684029?  ...
# 27  https://avatars.githubusercontent.com/u/41898282?  ...
# 28     https://avatars.githubusercontent.com/u/63482?  ...
# 29   https://avatars.githubusercontent.com/u/9650581?  ...
#
#     payload.forkee.license payload.forkee.allow_forking  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# 5                      NaN                          NaN
# 6                      NaN                          NaN
# 7                      NaN                          NaN
# 8                      NaN                          NaN
# 9                      NaN                          NaN
# 10                     NaN                          NaN
# 11                     NaN                          NaN
# 12                     NaN                          NaN
# 13                     NaN                          NaN
# 14                     NaN                          NaN
# 15                     NaN                          NaN
# 16                     NaN                          NaN
# 17                     NaN                          NaN
# 18                     NaN                          NaN
# 19                     NaN                          NaN
# 20                     NaN                          NaN
# 21                     NaN                          NaN
# 22                     NaN                          NaN
# 23                     NaN                         True
# 24                     NaN                          NaN
# 25                     NaN                          NaN
# 26                     NaN                          NaN
# 27                     NaN                          NaN
# 28                     NaN                          NaN
# 29                     NaN                          NaN
#
#    payload.forkee.is_template  payload.forkee.topics  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# 5                         NaN                    NaN
# 6                         NaN                    NaN
# 7                         NaN                    NaN
# 8                         NaN                    NaN
# 9                         NaN                    NaN
# 10                        NaN                    NaN
# 11                        NaN                    NaN
# 12                        NaN                    NaN
# 13                        NaN                    NaN
# 14                        NaN                    NaN
# 15                        NaN                    NaN
# 16                        NaN                    NaN
# 17                        NaN                    NaN
# 18                        NaN                    NaN
# 19                        NaN                    NaN
# 20                        NaN                    NaN
# 21                        NaN                    NaN
# 22                        NaN                    NaN
# 23                      False                     []
# 24                        NaN                    NaN
# 25                        NaN                    NaN
# 26                        NaN                    NaN
# 27                        NaN                    NaN
# 28                        NaN                    NaN
# 29                        NaN                    NaN
#
#     payload.forkee.visibility  payload.forkee.forks  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# 5                         NaN                   NaN
# 6                         NaN                   NaN
# 7                         NaN                   NaN
# 8                         NaN                   NaN
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 11                        NaN                   NaN
# 12                        NaN                   NaN
# 13                        NaN                   NaN
# 14                        NaN                   NaN
# 15                        NaN                   NaN
# 16                        NaN                   NaN
# 17                        NaN                   NaN
# 18                        NaN                   NaN
# 19                        NaN                   NaN
# 20                        NaN                   NaN
# 21                        NaN                   NaN
# 22                        NaN                   NaN
# 23                     public                   0.0
# 24                        NaN                   NaN
# 25                        NaN                   NaN
# 26                        NaN                   NaN
# 27                        NaN                   NaN
# 28                        NaN                   NaN
# 29                        NaN                   NaN
#
#    payload.forkee.open_issues payload.forkee.watchers  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# 8                         NaN                     NaN
# 9                         NaN                     NaN
# 10                        NaN                     NaN
# 11                        NaN                     NaN
# 12                        NaN                     NaN
# 13                        NaN                     NaN
# 14                        NaN                     NaN
# 15                        NaN                     NaN
# 16                        NaN                     NaN
# 17                        NaN                     NaN
# 18                        NaN                     NaN
# 19                        NaN                     NaN
# 20                        NaN                     NaN
# 21                        NaN                     NaN
# 22                        NaN                     NaN
# 23                        0.0                     0.0
# 24                        NaN                     NaN
# 25                        NaN                     NaN
# 26                        NaN                     NaN
# 27                        NaN                     NaN
# 28                        NaN                     NaN
# 29                        NaN                     NaN
#
#    payload.forkee.default_branch payload.forkee.public
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                          main                  True
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                           NaN                   NaN
#
# [30 rows x 444 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1637739385,
#  'iss_position': {'latitude': '51.0291', 'longitude': '171.5632'},
#  'message': 'success'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1637739535,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 536, 'risetime': 1637766652},
#   {'duration': 645, 'risetime': 1637772367},
#   {'duration': 660, 'risetime': 1637778159},
#   {'duration': 654, 'risetime': 1637783966},
#   {'duration': 593, 'risetime': 1637789779}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1637772367)
# Out:
# datetime.datetime(2021, 11, 24, 17, 46, 7)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_26336/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1637739535, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 536, 'risetime': 1637766652}, {'duration': 645, 'risetime': 1637772367}, {'duration': 660, 'risetime': 1637778159}, {'duration': 654, 'risetime': 1637783966}, {'duration': 593, 'risetime': 1637789779}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
